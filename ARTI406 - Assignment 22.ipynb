# %% [markdown]
# ARTI308 - Machine Learning
#
# # Assignment 2: Data Quality Assessment & Preprocessing
#
# In real-world machine learning projects, data is often:
# - Incomplete (missing values)
# - Noisy (outliers or random errors)
# - Inconsistent (wrong formats, mixed units)
#
# Before building any machine learning model, we must clean and prepare the data properly.
#
# ![step2.png](img/step2.png)
#
# In this lab, we will apply practical preprocessing techniques step by step.

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# ## 1. Load Dataset

# %%
pd.set_option("display.max_columns", None)

df = pd.read_csv('final_scout_not_dummy.csv')
df.head(10)
# Out:
#   make_model      body_type  price               vat       km  Type     Fuel  \
# 0    Audi A1         Sedans  15770    VAT deductible  56013.0  Used   Diesel
# 1    Audi A1         Sedans  14500  Price negotiable  80000.0  Used  Benzine
# 2    Audi A1         Sedans  14640    VAT deductible  83450.0  Used   Diesel
# 3    Audi A1         Sedans  14500    VAT deductible  73000.0  Used   Diesel
# 4    Audi A1         Sedans  16790    VAT deductible  16200.0  Used   Diesel
# 5    Audi A1         Sedans  15090    VAT deductible  63668.0  Used   Diesel
# 6    Audi A1  Station wagon  16422    VAT deductible  62111.0  Used   Diesel
# 7    Audi A1        Compact  14480    VAT deductible  14986.0  Used   Diesel
# 8    Audi A1         Sedans  16700    VAT deductible  57000.0  Used   Diesel
# 9    Audi A1         Sedans  17990    VAT deductible  16103.0  Used  Benzine
#
#    Gears                                Comfort_Convenience  \
# 0    7.0  Air conditioning,Armrest,Automatic climate con...
# 1    7.0  Air conditioning,Automatic climate control,Hil...
# 2    7.0  Air conditioning,Cruise control,Electrical sid...
# 3    6.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4    7.0  Air conditioning,Armrest,Automatic climate con...
# 5    7.0  Air conditioning,Armrest,Automatic climate con...
# 6    7.0  Air conditioning,Armrest,Automatic climate con...
# 7    7.0  Air conditioning,Armrest,Electrical side mirro...
# 8    7.0                     Air conditioning,Power windows
# 9    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 5  Bluetooth,Hands-free equipment,On-board comput...
# 6  Bluetooth,CD player,Hands-free equipment,On-bo...
# 7                                CD player,MP3,Radio
# 8                                              Radio
# 9                                              Radio
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
# 5  Alloy wheels,Sport package,Sport seats,Sport s...
# 6  Alloy wheels,Sport package,Sport seats,Sport s...
# 7                                       Alloy wheels
# 8                                       Alloy wheels
# 9                                       Alloy wheels
#
#                                      Safety_Security  age  Previous_Owners  \
# 0  ABS,Central door lock,Daytime running lights,D...  3.0              2.0
# 1  ABS,Central door lock,Central door lock with r...  2.0              1.0
# 2  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 3  ABS,Alarm system,Central door lock with remote...  3.0              1.0
# 4  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 5  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 6  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 7  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 8  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 9  ABS,Central door lock,Daytime running lights,D...  2.0              1.0
#
#    hp_kW  Inspection_new Paint_Type    Upholstery_type Gearing_Type  \
# 0   66.0               1   Metallic              Cloth    Automatic
# 1  141.0               0   Metallic              Cloth    Automatic
# 2   85.0               0   Metallic              Cloth    Automatic
# 3   66.0               0   Metallic              Cloth    Automatic
# 4   66.0               1   Metallic              Cloth    Automatic
# 5   85.0               0   Metallic  Part/Full Leather    Automatic
# 6   85.0               1   Metallic  Part/Full Leather    Automatic
# 7   66.0               1   Metallic              Cloth    Automatic
# 8   85.0               0   Metallic              Cloth    Automatic
# 9   70.0               0   Metallic              Cloth    Automatic
#
#    Displacement_cc  Weight_kg Drive_chain  cons_comb
# 0           1422.0     1220.0       front        3.8
# 1           1798.0     1255.0       front        5.6
# 2           1598.0     1135.0       front        3.8
# 3           1422.0     1195.0       front        3.8
# 4           1422.0     1135.0       front        4.1
# 5           1598.0     1135.0       front        3.5
# 6           1598.0     1195.0       front        3.7
# 7           1422.0     1180.0       front        3.7
# 8           1598.0     1275.0       front        3.7
# 9            999.0     1135.0       front        4.2

# %% [markdown]
# ## 2. Data Quality Assessment
# ### 2.1 Check Data Types
# Data types must match the real meaning of each column.
# For example:
# - `Date` should be datetime
# - `Revenue` should be numeric

# %%
df.dtypes
print("Dataset Shape:")
print(df.shape)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Dataset Shape:
# (15915, 23)
#
# Missing Values:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64
#
# Duplicate Rows:
# 1673

# %% [markdown]
# Data Quality Assessment
#
# The dataset contains both numerical and categorical features. Data types appear to be appropriate for most columns. Duplicate records were detected and may affect analysis results. Missing values were also checked as part of the data quality assessment process.

# %% [markdown]
# ### 2.2 Convert Incorrect Data Types
#
# The dataset does not contain Date or Amount columns. Therefore, no conversion to datetime or currency cleaning is required. Numerical columns such as price, km, Gears, age, hp_kW, Displacement_cc, Weight_kg, and cons_comb are already stored as numeric data types.

# %%
# 2.2 Check Data Types for Car Dataset

df.dtypes
# Out:
# make_model                 str
# body_type                  str
# price                    int64
# vat                        str
# km                     float64
# Type                       str
# Fuel                       str
# Gears                  float64
# Comfort_Convenience        str
# Entertainment_Media        str
# Extras                     str
# Safety_Security            str
# age                    float64
# Previous_Owners        float64
# hp_kW                  float64
# Inspection_new           int64
# Paint_Type                 str
# Upholstery_type            str
# Gearing_Type               str
# Displacement_cc        float64
# Weight_kg              float64
# Drive_chain                str
# cons_comb              float64
# dtype: object

# %% [markdown]
# ## 3. Handling Missing Values
# ### 3.1 Detect Missing Values
# Missing values reduce data quality and can affect model performance.

# %%
df.isna().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64

# %% [markdown]
# The output shows whether any column contains missing values.
# If all values are zero, the dataset is complete.
# If any column contains missing values, we must handle them.

# %% [markdown]
# ### 3.2 Demonstration: Introduce Artificial Missing Values
# ### Why?
#
# Since our dataset has no missing values, we introduce artificial ones *for learning purposes*.
#
# we will be running this line:
#
# `df_missing.loc[0:5, 'Amount'] = np.nan`
#
#
# - `df_missing`: The pandas DataFrame you are modifying.
#
# - `.loc[0:5, 'Amount']`: This uses the label-based indexer to select specific rows and columns.
#
# - `0:5`: Selects rows with index labels 0, 1, 2, 3, 4, and 5. In label-based indexing, the end index is inclusive.
#
# - `'Amount'`: Selects the column named 'Amount'.
#
# - `= np.nan`: Assigns the value np.nan (which stands for "Not a Number") to all the selected cells. This is the standard way to represent missing or null values in numerical columns in pandas. The column's data type will be converted to float

# %%
df_missing = df.copy()
df_missing.loc[0:5, 'price'] = np.nan
df_missing.isna().sum()
# Out:
# make_model             0
# body_type              0
# price                  6
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64

# %% [markdown]
# Now the Amount column contains missing values.

# %%
print("Original shape: ",df.shape)
print("After removing some values: ",df_missing.shape)
# Out:
# Original shape:  (15915, 23)
# After removing some values:  (15915, 23)

# %%
df_missing.head(10)
# Out:
#   make_model      body_type    price               vat       km  Type  \
# 0    Audi A1         Sedans      NaN    VAT deductible  56013.0  Used
# 1    Audi A1         Sedans      NaN  Price negotiable  80000.0  Used
# 2    Audi A1         Sedans      NaN    VAT deductible  83450.0  Used
# 3    Audi A1         Sedans      NaN    VAT deductible  73000.0  Used
# 4    Audi A1         Sedans      NaN    VAT deductible  16200.0  Used
# 5    Audi A1         Sedans      NaN    VAT deductible  63668.0  Used
# 6    Audi A1  Station wagon  16422.0    VAT deductible  62111.0  Used
# 7    Audi A1        Compact  14480.0    VAT deductible  14986.0  Used
# 8    Audi A1         Sedans  16700.0    VAT deductible  57000.0  Used
# 9    Audi A1         Sedans  17990.0    VAT deductible  16103.0  Used
#
#       Fuel  Gears                                Comfort_Convenience  \
# 0   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 1  Benzine    7.0  Air conditioning,Automatic climate control,Hil...
# 2   Diesel    7.0  Air conditioning,Cruise control,Electrical sid...
# 3   Diesel    6.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 5   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 6   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 7   Diesel    7.0  Air conditioning,Armrest,Electrical side mirro...
# 8   Diesel    7.0                     Air conditioning,Power windows
# 9  Benzine    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 5  Bluetooth,Hands-free equipment,On-board comput...
# 6  Bluetooth,CD player,Hands-free equipment,On-bo...
# 7                                CD player,MP3,Radio
# 8                                              Radio
# 9                                              Radio
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
# 5  Alloy wheels,Sport package,Sport seats,Sport s...
# 6  Alloy wheels,Sport package,Sport seats,Sport s...
# 7                                       Alloy wheels
# 8                                       Alloy wheels
# 9                                       Alloy wheels
#
#                                      Safety_Security  age  Previous_Owners  \
# 0  ABS,Central door lock,Daytime running lights,D...  3.0              2.0
# 1  ABS,Central door lock,Central door lock with r...  2.0              1.0
# 2  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 3  ABS,Alarm system,Central door lock with remote...  3.0              1.0
# 4  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 5  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 6  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 7  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 8  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 9  ABS,Central door lock,Daytime running lights,D...  2.0              1.0
#
#    hp_kW  Inspection_new Paint_Type    Upholstery_type Gearing_Type  \
# 0   66.0               1   Metallic              Cloth    Automatic
# 1  141.0               0   Metallic              Cloth    Automatic
# 2   85.0               0   Metallic              Cloth    Automatic
# 3   66.0               0   Metallic              Cloth    Automatic
# 4   66.0               1   Metallic              Cloth    Automatic
# 5   85.0               0   Metallic  Part/Full Leather    Automatic
# 6   85.0               1   Metallic  Part/Full Leather    Automatic
# 7   66.0               1   Metallic              Cloth    Automatic
# 8   85.0               0   Metallic              Cloth    Automatic
# 9   70.0               0   Metallic              Cloth    Automatic
#
#    Displacement_cc  Weight_kg Drive_chain  cons_comb
# 0           1422.0     1220.0       front        3.8
# 1           1798.0     1255.0       front        5.6
# 2           1598.0     1135.0       front        3.8
# 3           1422.0     1195.0       front        3.8
# 4           1422.0     1135.0       front        4.1
# 5           1598.0     1135.0       front        3.5
# 6           1598.0     1195.0       front        3.7
# 7           1422.0     1180.0       front        3.7
# 8           1598.0     1275.0       front        3.7
# 9            999.0     1135.0       front        4.2

# %% [markdown]
# ### Strategy 1: Remove Records
# This strategy removes records containing missing data.
# It works well if the number of missing rows is small.

# %%
df_removed = df_missing.dropna()
df_removed.shape
# Out:
# (15909, 23)

# %%
df_removed.isna().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64

# %% [markdown]
# The dataset now has fewer rows.
# If only a small portion of data was missing, this method is acceptable.
#
# However, removing too many rows can reduce model performance.

# %% [markdown]
# ### Strategy 2: Mean Imputation
#
# ![Mean.png](img\Mean.png)
#
# The mean represents the average value.
# It is commonly used for normally distributed data.

# %%
df_missing.head(10)
# Out:
#   make_model      body_type  price               vat       km  Type     Fuel  \
# 0    Audi A1         Sedans  15770    VAT deductible  56013.0  Used   Diesel
# 1    Audi A1         Sedans  14500  Price negotiable  80000.0  Used  Benzine
# 2    Audi A1         Sedans  14640    VAT deductible  83450.0  Used   Diesel
# 3    Audi A1         Sedans  14500    VAT deductible  73000.0  Used   Diesel
# 4    Audi A1         Sedans  16790    VAT deductible  16200.0  Used   Diesel
# 5    Audi A1         Sedans  15090    VAT deductible  63668.0  Used   Diesel
# 6    Audi A1  Station wagon  16422    VAT deductible  62111.0  Used   Diesel
# 7    Audi A1        Compact  14480    VAT deductible  14986.0  Used   Diesel
# 8    Audi A1         Sedans  16700    VAT deductible  57000.0  Used   Diesel
# 9    Audi A1         Sedans  17990    VAT deductible  16103.0  Used  Benzine
#
#    Gears                                Comfort_Convenience  \
# 0    7.0  Air conditioning,Armrest,Automatic climate con...
# 1    7.0  Air conditioning,Automatic climate control,Hil...
# 2    7.0  Air conditioning,Cruise control,Electrical sid...
# 3    6.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4    7.0  Air conditioning,Armrest,Automatic climate con...
# 5    7.0  Air conditioning,Armrest,Automatic climate con...
# 6    7.0  Air conditioning,Armrest,Automatic climate con...
# 7    7.0  Air conditioning,Armrest,Electrical side mirro...
# 8    7.0                     Air conditioning,Power windows
# 9    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 5  Bluetooth,Hands-free equipment,On-board comput...
# 6  Bluetooth,CD player,Hands-free equipment,On-bo...
# 7                                CD player,MP3,Radio
# 8                                              Radio
# 9                                              Radio
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
# 5  Alloy wheels,Sport package,Sport seats,Sport s...
# 6  Alloy wheels,Sport package,Sport seats,Sport s...
# 7                                       Alloy wheels
# 8                                       Alloy wheels
# 9                                       Alloy wheels
#
#                                      Safety_Security  age  Previous_Owners  \
# 0  ABS,Central door lock,Daytime running lights,D...  3.0              2.0
# 1  ABS,Central door lock,Central door lock with r...  2.0              1.0
# 2  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 3  ABS,Alarm system,Central door lock with remote...  3.0              1.0
# 4  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 5  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 6  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 7  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 8  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 9  ABS,Central door lock,Daytime running lights,D...  2.0              1.0
#
#    hp_kW  Inspection_new Paint_Type    Upholstery_type Gearing_Type  \
# 0   66.0               1   Metallic              Cloth    Automatic
# 1  141.0               0   Metallic              Cloth    Automatic
# 2   85.0               0   Metallic              Cloth    Automatic
# 3   66.0               0   Metallic              Cloth    Automatic
# 4   66.0               1   Metallic              Cloth    Automatic
# 5   85.0               0   Metallic  Part/Full Leather    Automatic
# 6   85.0               1   Metallic  Part/Full Leather    Automatic
# 7   66.0               1   Metallic              Cloth    Automatic
# 8   85.0               0   Metallic              Cloth    Automatic
# 9   70.0               0   Metallic              Cloth    Automatic
#
#    Displacement_cc  Weight_kg Drive_chain  cons_comb  Amount
# 0           1422.0     1220.0       front        3.8     NaN
# 1           1798.0     1255.0       front        5.6     NaN
# 2           1598.0     1135.0       front        3.8     NaN
# 3           1422.0     1195.0       front        3.8     NaN
# 4           1422.0     1135.0       front        4.1     NaN
# 5           1598.0     1135.0       front        3.5     NaN
# 6           1598.0     1195.0       front        3.7     NaN
# 7           1422.0     1180.0       front        3.7     NaN
# 8           1598.0     1275.0       front        3.7     NaN
# 9            999.0     1135.0       front        4.2     NaN

# %%
df_imputed_mean = df_missing.copy()

mean_value = df_imputed_mean['price'].mean()

df_imputed_mean['price'] = df_imputed_mean['price'].fillna(mean_value)

df_imputed_mean.isna().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64

# %%
df_imputed_mean.head(10)
# Out:
#   make_model      body_type         price               vat       km  Type  \
# 0    Audi A1         Sedans  18025.440128    VAT deductible  56013.0  Used
# 1    Audi A1         Sedans  18025.440128  Price negotiable  80000.0  Used
# 2    Audi A1         Sedans  18025.440128    VAT deductible  83450.0  Used
# 3    Audi A1         Sedans  18025.440128    VAT deductible  73000.0  Used
# 4    Audi A1         Sedans  18025.440128    VAT deductible  16200.0  Used
# 5    Audi A1         Sedans  18025.440128    VAT deductible  63668.0  Used
# 6    Audi A1  Station wagon  16422.000000    VAT deductible  62111.0  Used
# 7    Audi A1        Compact  14480.000000    VAT deductible  14986.0  Used
# 8    Audi A1         Sedans  16700.000000    VAT deductible  57000.0  Used
# 9    Audi A1         Sedans  17990.000000    VAT deductible  16103.0  Used
#
#       Fuel  Gears                                Comfort_Convenience  \
# 0   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 1  Benzine    7.0  Air conditioning,Automatic climate control,Hil...
# 2   Diesel    7.0  Air conditioning,Cruise control,Electrical sid...
# 3   Diesel    6.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 5   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 6   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 7   Diesel    7.0  Air conditioning,Armrest,Electrical side mirro...
# 8   Diesel    7.0                     Air conditioning,Power windows
# 9  Benzine    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 5  Bluetooth,Hands-free equipment,On-board comput...
# 6  Bluetooth,CD player,Hands-free equipment,On-bo...
# 7                                CD player,MP3,Radio
# 8                                              Radio
# 9                                              Radio
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
# 5  Alloy wheels,Sport package,Sport seats,Sport s...
# 6  Alloy wheels,Sport package,Sport seats,Sport s...
# 7                                       Alloy wheels
# 8                                       Alloy wheels
# 9                                       Alloy wheels
#
#                                      Safety_Security  age  Previous_Owners  \
# 0  ABS,Central door lock,Daytime running lights,D...  3.0              2.0
# 1  ABS,Central door lock,Central door lock with r...  2.0              1.0
# 2  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 3  ABS,Alarm system,Central door lock with remote...  3.0              1.0
# 4  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 5  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 6  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 7  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 8  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 9  ABS,Central door lock,Daytime running lights,D...  2.0              1.0
#
#    hp_kW  Inspection_new Paint_Type    Upholstery_type Gearing_Type  \
# 0   66.0               1   Metallic              Cloth    Automatic
# 1  141.0               0   Metallic              Cloth    Automatic
# 2   85.0               0   Metallic              Cloth    Automatic
# 3   66.0               0   Metallic              Cloth    Automatic
# 4   66.0               1   Metallic              Cloth    Automatic
# 5   85.0               0   Metallic  Part/Full Leather    Automatic
# 6   85.0               1   Metallic  Part/Full Leather    Automatic
# 7   66.0               1   Metallic              Cloth    Automatic
# 8   85.0               0   Metallic              Cloth    Automatic
# 9   70.0               0   Metallic              Cloth    Automatic
#
#    Displacement_cc  Weight_kg Drive_chain  cons_comb
# 0           1422.0     1220.0       front        3.8
# 1           1798.0     1255.0       front        5.6
# 2           1598.0     1135.0       front        3.8
# 3           1422.0     1195.0       front        3.8
# 4           1422.0     1135.0       front        4.1
# 5           1598.0     1135.0       front        3.5
# 6           1598.0     1195.0       front        3.7
# 7           1422.0     1180.0       front        3.7
# 8           1598.0     1275.0       front        3.7
# 9            999.0     1135.0       front        4.2

# %% [markdown]
# Missing values are now replaced with the average revenue.
# This preserves dataset size but may reduce variability.
# Mean imputation is sensitive to outliers.

# %% [markdown]
# ### Strategy 3: Median Imputation
#
# ![median_formula_2.png](img/median_formula_2.png)
# The median is more robust to outliers than the mean.
# It is preferred for skewed data.

# %%
df_imputed_median = df_missing.copy()

median_value = df_imputed_median['price'].median()

df_imputed_median['price'] = df_imputed_median['price'].fillna(median_value)

df_imputed_median.isna().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64

# %%
df_imputed_median.head(10)
# Out:
#   make_model      body_type    price               vat       km  Type  \
# 0    Audi A1         Sedans  16900.0    VAT deductible  56013.0  Used
# 1    Audi A1         Sedans  16900.0  Price negotiable  80000.0  Used
# 2    Audi A1         Sedans  16900.0    VAT deductible  83450.0  Used
# 3    Audi A1         Sedans  16900.0    VAT deductible  73000.0  Used
# 4    Audi A1         Sedans  16900.0    VAT deductible  16200.0  Used
# 5    Audi A1         Sedans  16900.0    VAT deductible  63668.0  Used
# 6    Audi A1  Station wagon  16422.0    VAT deductible  62111.0  Used
# 7    Audi A1        Compact  14480.0    VAT deductible  14986.0  Used
# 8    Audi A1         Sedans  16700.0    VAT deductible  57000.0  Used
# 9    Audi A1         Sedans  17990.0    VAT deductible  16103.0  Used
#
#       Fuel  Gears                                Comfort_Convenience  \
# 0   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 1  Benzine    7.0  Air conditioning,Automatic climate control,Hil...
# 2   Diesel    7.0  Air conditioning,Cruise control,Electrical sid...
# 3   Diesel    6.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 5   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 6   Diesel    7.0  Air conditioning,Armrest,Automatic climate con...
# 7   Diesel    7.0  Air conditioning,Armrest,Electrical side mirro...
# 8   Diesel    7.0                     Air conditioning,Power windows
# 9  Benzine    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 5  Bluetooth,Hands-free equipment,On-board comput...
# 6  Bluetooth,CD player,Hands-free equipment,On-bo...
# 7                                CD player,MP3,Radio
# 8                                              Radio
# 9                                              Radio
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
# 5  Alloy wheels,Sport package,Sport seats,Sport s...
# 6  Alloy wheels,Sport package,Sport seats,Sport s...
# 7                                       Alloy wheels
# 8                                       Alloy wheels
# 9                                       Alloy wheels
#
#                                      Safety_Security  age  Previous_Owners  \
# 0  ABS,Central door lock,Daytime running lights,D...  3.0              2.0
# 1  ABS,Central door lock,Central door lock with r...  2.0              1.0
# 2  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 3  ABS,Alarm system,Central door lock with remote...  3.0              1.0
# 4  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 5  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 6  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 7  ABS,Central door lock,Daytime running lights,D...  3.0              1.0
# 8  ABS,Central door lock,Driver-side airbag,Elect...  3.0              1.0
# 9  ABS,Central door lock,Daytime running lights,D...  2.0              1.0
#
#    hp_kW  Inspection_new Paint_Type    Upholstery_type Gearing_Type  \
# 0   66.0               1   Metallic              Cloth    Automatic
# 1  141.0               0   Metallic              Cloth    Automatic
# 2   85.0               0   Metallic              Cloth    Automatic
# 3   66.0               0   Metallic              Cloth    Automatic
# 4   66.0               1   Metallic              Cloth    Automatic
# 5   85.0               0   Metallic  Part/Full Leather    Automatic
# 6   85.0               1   Metallic  Part/Full Leather    Automatic
# 7   66.0               1   Metallic              Cloth    Automatic
# 8   85.0               0   Metallic              Cloth    Automatic
# 9   70.0               0   Metallic              Cloth    Automatic
#
#    Displacement_cc  Weight_kg Drive_chain  cons_comb
# 0           1422.0     1220.0       front        3.8
# 1           1798.0     1255.0       front        5.6
# 2           1598.0     1135.0       front        3.8
# 3           1422.0     1195.0       front        3.8
# 4           1422.0     1135.0       front        4.1
# 5           1598.0     1135.0       front        3.5
# 6           1598.0     1195.0       front        3.7
# 7           1422.0     1180.0       front        3.7
# 8           1598.0     1275.0       front        3.7
# 9            999.0     1135.0       front        4.2

# %% [markdown]
# Missing values are replaced with the middle value.
# This approach is safer when data contains extreme values.

# %% [markdown]
# ## 4. Handling Outliers
# Outliers are extreme values that can distort models.
# We will detect outliers using the IQR method.
#
# ![IQR.png](img/IQR.png)

# %%
plt.figure(figsize=(4,3))
sns.boxplot(x=df['price'])
plt.title("Boxplot of Revenue")
plt.show()

# %% [markdown]
# Points outside the whiskers represent potential outliers.
# These extreme revenue values may influence model predictions.

# %% [markdown]
# ### Detect Outliers using IQR
# **Method: Interquartile Range (IQR)**
#
# The IQR method defines outliers as values outside:
#
# `Q1 - 1.5×IQR`  and  `Q3 + 1.5×IQR`

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['price'] < lower) | (df['price'] > upper)]

outliers.head(15)
# Out:
#      make_model      body_type  price               vat       km  \
# 713     Audi A1         Sedans  37900    VAT deductible   7000.0
# 732     Audi A1         Sedans  35900    VAT deductible    200.0
# 3587    Audi A3         Sedans  64900    VAT deductible  35000.0
# 3589    Audi A3        Compact  39959    VAT deductible      7.0
# 3590    Audi A3         Sedans  62900    VAT deductible    700.0
# 3591    Audi A3        Compact  39575    VAT deductible      7.0
# 3592    Audi A3         Sedans  56900    VAT deductible   5200.0
# 3593    Audi A3         Sedans  58500    VAT deductible  10000.0
# 3594    Audi A3         Sedans  58990    VAT deductible   7500.0
# 3595    Audi A3  Station wagon  63900    VAT deductible     10.0
# 3596    Audi A3         Sedans  57400  Price negotiable  63000.0
# 3597    Audi A3    Convertible  56100    VAT deductible   8364.0
# 3598    Audi A3         Sedans  55000    VAT deductible  24000.0
# 3599    Audi A3         Sedans  55000    VAT deductible  30000.0
# 3600    Audi A3         Sedans  53000    VAT deductible   4000.0
#
#                 Type     Fuel  Gears  \
# 713             Used  Benzine    6.0
# 732   Pre-registered  Benzine    7.0
# 3587            Used  Benzine    7.0
# 3589             New  Benzine    7.0
# 3590            Used  Benzine    7.0
# 3591             New  Benzine    7.0
# 3592            Used  Benzine    7.0
# 3593            Used  Benzine    7.0
# 3594            Used  Benzine    7.0
# 3595            Used  Benzine    7.0
# 3596            Used  Benzine    7.0
# 3597            Used  Benzine    7.0
# 3598            Used  Benzine    7.0
# 3599            Used  Benzine    7.0
# 3600            Used  Benzine    7.0
#
#                                     Comfort_Convenience  \
# 713   Air conditioning,Seat ventilation,Split rear s...
# 732   Air conditioning,Armrest,Auxiliary heating,Cru...
# 3587  Air conditioning,Seat ventilation,Split rear s...
# 3589  Air conditioning,Armrest,Automatic climate con...
# 3590  Air conditioning,Seat ventilation,Split rear s...
# 3591  Air conditioning,Armrest,Automatic climate con...
# 3592  Air conditioning,Air suspension,Armrest,Automa...
# 3593  Air conditioning,Seat ventilation,Split rear s...
# 3594  Air conditioning,Automatic climate control,Cru...
# 3595  Air conditioning,Armrest,Automatic climate con...
# 3596  Air conditioning,Air suspension,Armrest,Automa...
# 3597  Air conditioning,Armrest,Automatic climate con...
# 3598  Air conditioning,Seat ventilation,Split rear s...
# 3599  Air conditioning,Seat ventilation,Split rear s...
# 3600  Air conditioning,Air suspension,Armrest,Automa...
#
#                                     Entertainment_Media  \
# 713                                     Bluetooth,Radio
# 732   Bluetooth,Digital radio,Hands-free equipment,O...
# 3587                                              Radio
# 3589                  CD player,On-board computer,Radio
# 3590                                    Bluetooth,Radio
# 3591                  CD player,On-board computer,Radio
# 3592  Bluetooth,CD player,Digital radio,Hands-free e...
# 3593                                              Radio
# 3594  Bluetooth,CD player,Hands-free equipment,On-bo...
# 3595  Bluetooth,CD player,Digital radio,Hands-free e...
# 3596  Bluetooth,CD player,Hands-free equipment,On-bo...
# 3597                  CD player,On-board computer,Radio
# 3598                                              Radio
# 3599                                              Radio
# 3600  Bluetooth,CD player,Digital radio,Hands-free e...
#
#                                                  Extras  \
# 713                       Alloy wheels,Sport suspension
# 732   Alloy wheels,Sport seats,Sport suspension,Touc...
# 3587                                       Alloy wheels
# 3589          Alloy wheels,Sport seats,Sport suspension
# 3590                                       Alloy wheels
# 3591          Alloy wheels,Sport seats,Sport suspension
# 3592  Alloy wheels,Shift paddles,Sport package,Sport...
# 3593                                       Alloy wheels
# 3594  Alloy wheels,Sport package,Sport seats,Sport s...
# 3595  Alloy wheels,Shift paddles,Ski bag,Sport packa...
# 3596  Alloy wheels,Sport seats,Sport suspension,Tune...
# 3597  Alloy wheels,Shift paddles,Sport seats,Sport s...
# 3598                                       Alloy wheels
# 3599                                       Alloy wheels
# 3600  Alloy wheels,Catalytic Converter,Shift paddles...
#
#                                         Safety_Security  age  Previous_Owners  \
# 713   ABS,Alarm system,Central door lock,Driver-side...  0.0              1.0
# 732   ABS,Alarm system,Central door lock,Central doo...  0.0              1.0
# 3587  Adaptive Cruise Control,Alarm system,Central d...  1.0              1.0
# 3589  ABS,Alarm system,Central door lock,Driver-side...  1.0              1.0
# 3590  ABS,Adaptive Cruise Control,Alarm system,Centr...  0.0              1.0
# 3591  ABS,Alarm system,Central door lock,Driver-side...  0.0              1.0
# 3592  ABS,Adaptive Cruise Control,Adaptive headlight...  1.0              1.0
# 3593  Adaptive Cruise Control,Alarm system,Central d...  1.0              1.0
# 3594  ABS,Adaptive Cruise Control,Adaptive headlight...  1.0              1.0
# 3595  ABS,Adaptive Cruise Control,Adaptive headlight...  0.0              1.0
# 3596  ABS,Adaptive Cruise Control,Adaptive headlight...  1.0              1.0
# 3597  ABS,Alarm system,Central door lock,Driver-side...  1.0              1.0
# 3598  Adaptive Cruise Control,Alarm system,Central d...  2.0              1.0
# 3599  Adaptive Cruise Control,Alarm system,Central d...  1.0              1.0
# 3600  Adaptive Cruise Control,Adaptive headlights,Al...  1.0              1.0
#
#       hp_kW  Inspection_new Paint_Type    Upholstery_type    Gearing_Type  \
# 713   147.0               0   Metallic              Cloth  Semi-automatic
# 732    85.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3587  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3589   85.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3590  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3591   85.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3592  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3593  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3594  228.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3595  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3596  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3597  228.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3598  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3599  294.0               0   Metallic  Part/Full Leather  Semi-automatic
# 3600  294.0               0   Metallic  Part/Full Leather  Semi-automatic
#
#       Displacement_cc  Weight_kg Drive_chain  cons_comb
# 713            1984.0     1240.0       front        6.0
# 732             999.0     1230.0       front        4.8
# 3587           2480.0     1585.0       front        8.3
# 3589            999.0     1155.0       front        4.5
# 3590           2480.0     1585.0       front        8.3
# 3591            999.0     1155.0       front        4.5
# 3592           2480.0     1585.0         4WD        8.3
# 3593           2480.0     1585.0       front        8.3
# 3594           1984.0     1360.0         4WD        6.5
# 3595           2480.0     1585.0       front        8.3
# 3596           2480.0     1585.0         4WD        8.3
# 3597           1984.0     1635.0         4WD        7.1
# 3598           2480.0     1585.0       front        8.3
# 3599           2480.0     1590.0       front        8.3
# 3600           2480.0     1590.0       front        8.3

# %% [markdown]
# The output displays records considered extreme based on statistical boundaries.
# These may be valid high-value transactions or potential data errors.

# %% [markdown]
# ### Remove Outliers
# We remove values outside the acceptable range.

# %%
df_no_outliers = df[
    (df['price'] >= lower) &
    (df['price'] <= upper)
]

print("Original Shape:", df.shape)
print("After removing outliers:", df_no_outliers.shape)
# Out:
# Original Shape: (15915, 23)
# After removing outliers: (15436, 23)

# %% [markdown]
# The dataset size is slightly reduced.
# Removing outliers reduces distortion but may also remove important rare events.
#
# #### Important Note on Removing Outliers
#
# Not all outliers are errors.
#
# Some extreme values may represent rare but important real-world events.
# For example, in a sales dataset, a very large transaction might correspond to a bulk corporate order or a seasonal promotion.
#
# If we remove such values blindly, we may lose valuable information and bias the analysis.
#
# Before removing outliers, we should always ask:
# - Is this value a data entry mistake?
# - Or is it a valid but rare observation?

# %% [markdown]
# ### Capping Outliers (Percentile Method)
# Instead of removing outliers, we replace extreme values with percentile limits.
#
# ![percentile.png](img/percentile.png)

# %%
lower_cap = df['price'].quantile(0.05)
upper_cap = df['price'].quantile(0.95)

df_capped = df.copy()

df_capped['price'] = df_capped['price'].clip(
    lower_cap,
    upper_cap
)

# %% [markdown]
# ## 5. Data Transformation – Normalization
# Normalization scales numerical features to a similar range.
# This ensures that no feature influences the model simply because it has larger numerical values.
#
# ### Min-Max Normalization
# Min-Max normalization rescales numerical values to a fixed range, usually between 0 and 1.
#
# It works using the formula:
# ![min_max.png](img/min_max.png)
#
# This method preserves the original distribution shape and relative ordering of values.
#
# Min-Max normalization is especially useful for distance-based models such as:
# - K-Nearest Neighbors (KNN)
# - K-Means clustering
# - Support Vector Machines (SVM)
#
# These models rely on distance calculations, and if features are on very different scales, one feature can dominate the distance computation.

# %%
df_no_outliers[
    ['price','km','Gears','age']
].head()
# Out:
#    price       km  Gears  age
# 0  15770  56013.0    7.0  3.0
# 1  14500  80000.0    7.0  2.0
# 2  14640  83450.0    7.0  3.0
# 3  14500  73000.0    6.0  3.0
# 4  16790  16200.0    7.0  3.0

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_scaled = df_no_outliers[
    ['price','km','Gears','age']
].copy()

df_scaled[['price','km','Gears','age']] = scaler.fit_transform(df_scaled)

df_scaled.head()
# Out:
#       price        km     Gears       age
# 0  0.354464  0.176697  0.666667  1.000000
# 1  0.312858  0.252366  0.666667  0.666667
# 2  0.317445  0.263249  0.666667  1.000000
# 3  0.312858  0.230284  0.333333  1.000000
# 4  0.387879  0.051104  0.666667  1.000000

# %% [markdown]
# After applying Min-Max normalization, all numerical values are scaled to the range between 0 and 1.
#
# The smallest value in each feature becomes 0, and the largest becomes 1.
# All other values are proportionally mapped between these two limits.
#
# Importantly, normalization does NOT change the relative relationships between data points.
# If one transaction originally had higher revenue than another, it will still have a higher normalized value.

# %% [markdown]
# ### Z-Score Normalization
# Z-score standardization transforms the data so that:
#
# - The mean of each feature becomes 0
# - The standard deviation becomes 1
#
# This is done by subtracting the mean and dividing by the standard deviation:
#
# ![zscore.png](img/zscore.png)
#
# This method keeps the shape of the distribution but rescales it around zero.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_standardized = df_no_outliers[
    ['price','km','Gears','age']
].copy()

df_standardized[['price','km','Gears','age']] = scaler.fit_transform(
    df_standardized
)

df_standardized.head()
# Out:
#       price        km     Gears       age
# 0 -0.249793  0.619972  1.549557  1.410404
# 1 -0.456111  1.265080  1.549557  0.513740
# 2 -0.433367  1.357865  1.549557  1.410404
# 3 -0.456111  1.076822  0.114362  1.410404
# 4 -0.084088 -0.450763  1.549557  1.410404

# %% [markdown]
# After standardization, the numerical features are centered around 0.
# Values above the original mean become **positive**, and values below the mean become **negative**.
#
# The standard deviation of each feature becomes approximately 1, meaning the spread of the data is standardized.
#
# This transformation is especially useful for:
# - Linear regression
# - Support Vector Machines (SVM)
# - PCA
#
# Because these models assume features are centered and scaled similarly.

# %% [markdown]
# ## Check Correlation Before Applying PCA
#
# we will check whether numerical features are correlated. If features are strongly correlated, they contain overlapping information.
#
# - **Correlation close to 1**  → Strong positive linear relationship
#   (As one feature increases, the other also increases.)
#
# - **Correlation close to -1** → Strong negative linear relationship
#   (As one feature increases, the other decreases.)
#
# - **Correlation close to 0**  → Weak or no linear relationship
#   (The features do not move together in a predictable linear way.)
#
# In such cases, dimensionality reduction using PCA is meaningful
# because we can combine correlated features into fewer components.

# %%
plt.figure(figsize=(6,4))

sns.heatmap(
    df_standardized[
        ['price','km','Gears','age']
    ].corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap Before PCA")
plt.show()

# %% [markdown]
# The heatmap shows the correlation between the numerical features:
#
# - The diagonal values are 1 because each feature is perfectly correlated with itself.
# - The correlation between `Amount` and `Boxes Shipped` is approximately *-0.013*.
#
# A correlation value close to 0 indicates that there is almost **NO linear** relationship between the two features.
#
# This means that `Amount` and `Boxes Shipped` do not move together in a predictable linear pattern.
#
# Since PCA is most useful when features are strongly correlated,
# the benefit of dimensionality reduction in this case may be limited.
#
# Therefore, applying PCA here is mainly for demonstration purposes rather than necessity.

# %% [markdown]
# ## 6. Data Reduction – Principal Component Analysis (PCA)
#
# Principal Component Analysis (PCA) is a dimensionality reduction technique.
#
# Instead of working directly with the original features, PCA creates new features called **principal components**.
#
# These components:
#
# - Are linear combinations of the original features
# - Are uncorrelated with each other
# - Capture variance in descending order (from most important to least)
#
# The first principal component (PC1) captures the largest possible variance in the dataset.
#
# The second principal component (PC2) captures the next largest variance, while being orthogonal (perpendicular) to PC1.
#
# This allows us to reduce dimensionality while retaining most of the important information in the data.

# %% [markdown]
# ### Visual Intuition
#
# Imagine we have two features:
#
# X1 = Amount
# X2 = Boxes Shipped
#
# If we plot the data points, they may look like this:
#
#               X2
#                |
#                |
#                |        *
#                |      *
#                |    *
#                |  *
#                | *
#                |________________________ X1
#
# Notice that the points follow a diagonal pattern.
# This means the two features are correlated and contain overlapping information.
#
# Instead of keeping both X1 and X2 separately,
# PCA finds the direction where the data varies the most.
#
# That direction becomes **Principal Component 1 (PC1)**.
#
#               X2
#                |
#                |        *
#                |      *
#                |    *
#                |  *
#                | *
#                |________________________ X1
#                     \
#                      \
#                       \
#                        \
#                         → PC1 (maximum variance direction)
#
# PC2 is the direction perpendicular to PC1.
#
# If most of the variation is along PC1,
# then PC1 alone captures most of the dataset’s information.
#
# In that case, we can reduce:
#
# 2 features → 1 feature (PC1)
#
# while keeping most of the variance.

# %%
from sklearn.decomposition import PCA

X = df_standardized[['price', 'km', 'Gears', 'age']]

pca = PCA(n_components=2)

principal_components = pca.fit_transform(X)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.54687231 0.31575379]

# %% [markdown]
# The `Explained Variance Ratio` indicates how much of the total information (variance) is captured by each principal component.
#
# For example:
# - If PC1 explains 85% of the variance, it means that one new feature already summarizes most of the dataset's information.
# - If PC1 and PC2 together explain nearly 100%, then very little information is lost.
#
# When most of the variance is captured by fewer components, dimensionality reduction is considered effective.
#
# This helps simplify models, reduce computational cost, and sometimes improve generalization performance.

# %% [markdown]
# ### The first principal component (PC1) explained 54.69% of the variance, while the second principal component (PC2) explained 31.58%. Together, they explained 86.27% of the total variance. This means that the first two principal components preserve most of the information in the dataset, making PCA effective for dimensionality reduction.

# %%
# # In addition to the heatmap, we can visualize the relationship between two features using a scatter plot. 
# # A scatter plot allows us to observe whether the features exhibit a linear pattern, meaning whether they increase or decrease together in a consistent way.


# plt.figure(figsize=(6,4))
# plt.scatter(df_standardized['Amount'], df_standardized['Boxes Shipped'])
# plt.xlabel("Amount (Standardized)")
# plt.ylabel("Boxes Shipped (Standardized)")
# plt.title("Scatter Plot: Amount vs Boxes Shipped")
# plt.show()

# %%
plt.figure(figsize=(6,4))

plt.scatter(
    principal_components[:,0],
    principal_components[:,1]
)

plt.title("PCA Projection")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()

# %% [markdown]
# Each point in this plot represents one sales transaction.
#
# The axes no longer represent the original features (Amount and Boxes Shipped).
# Instead:
#
# - The horizontal axis represents Principal Component 1 (PC1).
# - The vertical axis represents Principal Component 2 (PC2).
#
# PC1 captures the direction of maximum variance in the data.
# PC2 captures the second most important direction, perpendicular to PC1.
#
# The spread of points along the horizontal direction indicates how much variation is captured by PC1.
# If most of the spread appears horizontally, it suggests that PC1 captures most of the dataset's information.
#
# This projection allows us to visualize high-dimensional data in a lower-dimensional space.

# %% [markdown]
# ### Task 2 (Why did you choose Median?)
#
# Median imputation was selected to handle missing values in the price column because car prices often contain extreme values and outliers. Unlike the mean, the median is not heavily affected by unusually high or low prices. Therefore, it provides a more reliable representation of the central tendency of the data and helps preserve the overall distribution.

# %% [markdown]
# # Assignment
#
# In this assignment, you will:
# - **Task 1**
# Identify data quality issues in the dataset.
#
# - **Task 2**
# Apply one missing value strategy and explain why.
#
# - **Task 3**
# Detect and handle outliers using IQR.
#
# - **Task 4**
# Normalize numerical features using both Min-Max and Z-score.
#
# - **Task 5**
# Apply PCA and interpret explained variance.
#
#
# End of Assignment 2
